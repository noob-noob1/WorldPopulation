# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
final_df = pd.read_csv('WorldPopulation_Gro+Education.csv')

# %%
final_df.head()
# Out:
#    Unnamed: 0     Entity_x Code  Year_x  \
# 0           0  Afghanistan  AFG    1950
# 1           1  Afghanistan  AFG    1951
# 2           2  Afghanistan  AFG    1952
# 3           3  Afghanistan  AFG    1953
# 4           4  Afghanistan  AFG    1954
#
#    Population growth rate - Sex: all - Age: all - Variant: estimates  date  \
# 0                                              1.275                  1950
# 1                                              1.360                  1951
# 2                                              1.374                  1952
# 3                                              1.335                  1953
# 4                                              1.394                  1954
#
#       Entity_y  Year_y  Population - Education: Post Secondary  \
# 0  Afghanistan    1950                                   800.0
# 1  Afghanistan    1950                                   960.0
# 2  Afghanistan    1950                                  1120.0
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13825 entries, 0 to 13824
# Data columns (total 15 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   Unnamed: 0                                                         13825 non-null  int64
#  1   Entity_x                                                           13825 non-null  object
#  2   Code                                                               13825 non-null  object
#  3   Year_x                                                             13825 non-null  int64
#  4   Population growth rate - Sex: all - Age: all - Variant: estimates  13825 non-null  float64
#  5   date                                                               13825 non-null  int64
#  6   Entity_y                                                           13825 non-null  object
# ...

# %%
final_df = final_df.rename(columns={'Population - Education: Post Secondary': 'Education_Post_Secondary',
                                    'Population - Education: Upper Secondary':'Education_Upper_Secondary',
                                    'Population - Education: Lower Secondary':'Education_Lower_Secondary',
                                    'Population - Education: Incomplete Primary':'Education_Incomplete_Primary',
                                    'Population - Education: No Education':'Education_No_Education',
                                    'Population - Education: Under 15':'Education_Under_15',
                                    'Population growth rate - Sex: all - Age: all - Variant: estimates':'Growth_Rate',
                                    'Population - Education: Primary':'Education_Primary'	})

# %%
final_df = final_df.drop(columns=['Unnamed: 0'], axis=1)
final_df = final_df.drop(columns=['Year_y'], axis=1)
final_df = final_df.drop(columns=['date'], axis=1)
final_df = final_df.drop(columns=['Entity_y'], axis=1)

# %%
final_df
# Out:
#           Entity_x Code  Year_x  Growth_Rate  Education_Post_Secondary  \
# 0      Afghanistan  AFG    1950        1.275                     800.0
# 1      Afghanistan  AFG    1951        1.360                     960.0
# 2      Afghanistan  AFG    1952        1.374                    1120.0
# 3      Afghanistan  AFG    1953        1.335                    1280.0
# 4      Afghanistan  AFG    1954        1.394                    1440.0
# ...            ...  ...     ...          ...                       ...
# 13820     Zimbabwe  ZWE    2019        1.609                  930440.0
# 13821     Zimbabwe  ZWE    2020        1.709                  980200.0
# 13822     Zimbabwe  ZWE    2021        1.743                 1036920.0
# 13823     Zimbabwe  ZWE    2022        1.670                 1093640.0
# 13824     Zimbabwe  ZWE    2023        1.684                 1150360.0
#
#        Education_Upper_Secondary  Education_Lower_Secondary  \
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13825 entries, 0 to 13824
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Entity_x                      13825 non-null  object
#  1   Code                          13825 non-null  object
#  2   Year_x                        13825 non-null  int64
#  3   Growth_Rate                   13825 non-null  float64
#  4   Education_Post_Secondary      13825 non-null  float64
#  5   Education_Upper_Secondary     13825 non-null  float64
#  6   Education_Lower_Secondary     13825 non-null  float64
#  7   Education_Primary             13825 non-null  float64
#  8   Education_Incomplete_Primary  13825 non-null  float64
#  9   Education_No_Education        13825 non-null  float64
#  10  Education_Under_15            13825 non-null  float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 1.2+ MB

# %%
final_df.shape
# Out:
# (13825, 11)

# %%
final_df.describe()
# Out:
#              Year_x   Growth_Rate  Education_Post_Secondary  \
# count  13825.000000  13825.000000              1.382500e+04
# mean    1986.817360      1.793825              3.638751e+06
# std       21.496669      1.900834              3.385761e+07
# min     1950.000000    -71.064000              0.000000e+00
# 25%     1968.000000      0.811000              1.410000e+04
# 50%     1987.000000      1.801000              1.289800e+05
# 75%     2006.000000      2.682000              8.158000e+05
# max     2023.000000     37.887000              1.013370e+09
#
#        Education_Upper_Secondary  Education_Lower_Secondary  \
# count               1.382500e+04               1.382500e+04
# mean                7.915329e+06               7.618123e+06
# std                 6.673727e+07               6.391134e+07
# min                 0.000000e+00               0.000000e+00
# 25%                 3.930000e+04               5.108000e+04
# 50%                 3.335800e+05               3.802000e+05
# ...

# %%
sns.histplot(final_df['Education_Post_Secondary'], kde=True, bins=100)
plt.title('Histogram of Age')
plt.xlabel('Education_Post_Secondary')
plt.ylabel('Frequency')
plt.show()

# %%
sns.scatterplot(y=final_df['Year_x'], x=final_df['Education_Post_Secondary'],data=final_df)
# Out:
# <Axes: xlabel='Education_Post_Secondary', ylabel='Year_x'>

# %%
final_df.corr(numeric_only=True)
# Out:
#                                 Year_x  Growth_Rate  Education_Post_Secondary  \
# Year_x                        1.000000    -0.180797                  0.086608
# Growth_Rate                  -0.180797     1.000000                 -0.039104
# Education_Post_Secondary      0.086608    -0.039104                  1.000000
# Education_Upper_Secondary     0.075111    -0.038387                  0.986052
# Education_Lower_Secondary     0.061534    -0.034456                  0.940797
# Education_Primary             0.030168    -0.021799                  0.851391
# Education_Incomplete_Primary  0.022115    -0.009894                  0.822555
# Education_No_Education       -0.001387     0.002775                  0.714173
# Education_Under_15            0.025591    -0.010542                  0.834613
#
#                               Education_Upper_Secondary  \
# Year_x                                         0.075111
# Growth_Rate                                   -0.038387
# ...

# %%
sns.heatmap(final_df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >
